# %% [markdown]
# ASSIGNMENT 3

# %%
from google.colab import files

uploaded = files.upload()

print(uploaded)
# Out:
#      <input type="file" id="files-a4560e65-39fb-4f73-a797-2eec54e0dd1c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a4560e65-39fb-4f73-a797-2eec54e0dd1c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving StudentsPerformance.csv to StudentsPerformance.csv
# ...

# %%
# !ls
# Out:
# sample_data  StudentsPerformance.csv

# %%
import pandas as pd

# %%
students = pd.read_csv(r"StudentsPerformance.csv")
students.head()
# Out:
#    gender race/ethnicity  ... reading score writing score
# 0  female        group B  ...            72            74
# 1  female        group C  ...            90            88
# 2  female        group B  ...            95            93
# 3    male        group A  ...            57            44
# 4    male        group C  ...            78            75
#
# [5 rows x 8 columns]

# %%
students.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
students.iloc[0:9 ,0:3]
# Out:
#    gender race/ethnicity parental level of education
# 0  female        group B           bachelor's degree
# 1  female        group C                some college
# 2  female        group B             master's degree
# 3    male        group A          associate's degree
# 4    male        group C                some college
# 5  female        group B          associate's degree
# 6  female        group B                some college
# 7    male        group B                some college
# 8    male        group D                 high school

# %%
students.plot.scatter("writing score", "reading score", figsize=(8, 2))

# %%
import seaborn as sns
a=sns.countplot(data=students, x="parental level of education")

# %% [markdown]
# VISUALIZATION IS THE PICTORIAL REPRESENTATION OF DATA,ie, in a grphical manner
